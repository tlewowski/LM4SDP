# %%
import pandas as pd
METRIC_SET_MAPPING = {
    "none": "NONE",
    "all-non-null-numeric": "ALL",
    "pydriller": "PyD",
    "product": "PD",
    "process": "PR",
    "javametrics-numeric": "JM",
    "javametrics2": "JM2",
    "javametrics2-process": "JM2R",
    "javametrics2-product": "JM2D",
    "pmd": "PMD"
}

MODEL_NAME_MAPPING = {
    "basic-linear-ridge": "BLR",
    "unscaled-linear": "ULR",
    "basic-randomforest": "BRF",
    "unscaled-randomforest": "URF",
    "unscaled-decisiontree": "UDT",
    "basic-adaboost": "BAB",
    "basic-gradientboost": "BGB"
}

PROJECT_NAME_MAPPING = {
    "hadoop-hdfs": "HDFS",
    "hadoop-mapreduce": "MapReduce",
    "spark": "Spark",
    "activemq": "ActiveMQ",
    "zookeeper": "Zookeeper",
    "hive": "Hive",
    "ignite": "Ignite",
    "flink": "Flink",
    "cassandra": "Cassandra",
    "camel": "Camel",
    "hbase": "HBase"
}

partial_results = [
    "../../data/experiment3-final/r_1.csv",
    "../../data/experiment3-final/r_2.csv",
    "../../data/experiment3-final/r_3.csv",
    "../../data/experiment3-final/r_4.csv"
]

results = pd.concat([pd.read_csv(filepath_or_buffer=p, sep=',') for p in partial_results])
results[["TARGET", "MODEL", "METRICS", "SMELLS", "PROJECT", "ITERATION"]] = results.name.str.split("_", expand = True)
results
# Out:
#      model_num            metric_set  \
# 0            0               process
# 1            1               process
# 2            2               process
# 3            3               process
# 4            4               process
# ..         ...                   ...
# 751        751  all-non-null-numeric
# 752        752  all-non-null-numeric
# 753        753  all-non-null-numeric
# 754        754  all-non-null-numeric
# 755        755  all-non-null-numeric
#
#                                                   name             model_type  \
# 0    DEFECTS_basic-linear-ridge_process_nosmells_ac...     basic-linear-ridge
# 1    DEFECTS_basic-linear-ridge_process_smells_acti...     basic-linear-ridge
# 2    DEFECTS_basic-linear-ridge_process_nosmells_ca...     basic-linear-ridge
# 3    DEFECTS_basic-linear-ridge_process_smells_came...     basic-linear-ridge
# 4    DEFECTS_basic-linear-ridge_process_nosmells_ca...     basic-linear-ridge
# ..                                                 ...                    ...
# 751  DEFECTS_unscaled-decisiontree_all-non-null-num...  unscaled-decisiontree
# 752  DEFECTS_unscaled-decisiontree_all-non-null-num...  unscaled-decisiontree
# 753  DEFECTS_unscaled-decisiontree_all-non-null-num...  unscaled-decisiontree
# 754  DEFECTS_unscaled-decisiontree_all-non-null-num...  unscaled-decisiontree
# 755  DEFECTS_unscaled-decisiontree_all-non-null-num...  unscaled-decisiontree
#
#      smell_models  real_mcc   real_f1  real_precision  real_recall  \
# 0           False  0.257831  0.341822        0.547022     0.248575
# 1            True  0.302461  0.413245        0.543554     0.333333
# 2           False  0.147381  0.294825        0.201429     0.549708
# 3            True  0.153425  0.298779        0.203684     0.560429
# 4           False  0.284922  0.574899        0.539696     0.615014
# ..            ...       ...       ...             ...          ...
# 751          True  0.199804  0.544735        0.545166     0.544304
# 752         False  0.256431  0.547038        0.596958     0.504823
# 753          True  0.242811  0.531915        0.592885     0.482315
# 754         False  0.255142  0.573018        0.546419     0.602339
# 755          True  0.235201  0.567935        0.530457     0.611111
#
#      real_accuracy  ...  fake_total  fit_time_sec  test_time_sec  \
# 0         0.780607  ...       21123         2.609          0.125
# 1         0.783056  ...       21689         4.313          0.171
# 2         0.643436  ...      113746         2.609          0.781
# 3         0.643304  ...      115746         4.156          1.110
# 4         0.652531  ...       41595         3.515          0.281
# ..             ...  ...         ...           ...            ...
# 751       0.607509  ...        7588        47.031          0.062
# 752       0.641626  ...        9329        46.062          0.032
# 753       0.636113  ...        9329        47.046          0.047
# 754       0.634088  ...       10122        45.172          0.062
# 755       0.620977  ...       10122        44.344          0.047
#
#      preparation_time_sec   TARGET                  MODEL  \
# 0                   3.563  DEFECTS     basic-linear-ridge
# 1                   4.047  DEFECTS     basic-linear-ridge
# 2                   5.157  DEFECTS     basic-linear-ridge
# 3                   7.641  DEFECTS     basic-linear-ridge
# 4                   8.500  DEFECTS     basic-linear-ridge
# ..                    ...      ...                    ...
# 751                 6.485  DEFECTS  unscaled-decisiontree
# 752                 6.469  DEFECTS  unscaled-decisiontree
# 753                 6.657  DEFECTS  unscaled-decisiontree
# 754                 6.359  DEFECTS  unscaled-decisiontree
# 755                 6.844  DEFECTS  unscaled-decisiontree
#
#                   METRICS    SMELLS    PROJECT  ITERATION
# 0                 process  nosmells   activemq    0.scops
# 1                 process    smells   activemq    0.scops
# 2                 process  nosmells      camel    0.scops
# 3                 process    smells      camel    0.scops
# 4                 process  nosmells  cassandra    0.scops
# ..                    ...       ...        ...        ...
# 751  all-non-null-numeric    smells      spark    2.scops
# 752  all-non-null-numeric  nosmells   zeppelin    2.scops
# 753  all-non-null-numeric    smells   zeppelin    2.scops
# 754  all-non-null-numeric  nosmells  zookeeper    2.scops
# 755  all-non-null-numeric    smells  zookeeper    2.scops
#
# [3024 rows x 36 columns]

# %%
description = results.groupby(["model_type", "metric_set", "smell_models", "PROJECT"]).describe()
description
# Out:
#                                                                   model_num  \
#                                                                       count
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq       12.0
#                                                         camel          12.0
#                                                         cassandra      12.0
#                                                         flink          12.0
#                                                         groovy         12.0
# ...                                                                     ...
# unscaled-randomforest pydriller            True         ignite         12.0
#                                                         kafka          12.0
#                                                         spark          12.0
#                                                         zeppelin       12.0
#                                                         zookeeper      12.0
#
#                                                                           \
#                                                                     mean
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   420.0
#                                                         camel      422.0
#                                                         cassandra  424.0
#                                                         flink      426.0
#                                                         groovy     428.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     383.0
#                                                         kafka      385.0
#                                                         spark      387.0
#                                                         zeppelin   389.0
#                                                         zookeeper  391.0
#
#                                                                                \
#                                                                           std
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   214.906322
#                                                         camel      214.906322
#                                                         cassandra  214.906322
#                                                         flink      214.906322
#                                                         groovy     214.906322
# ...                                                                       ...
# unscaled-randomforest pydriller            True         ignite     214.906322
#                                                         kafka      214.906322
#                                                         spark      214.906322
#                                                         zeppelin   214.906322
#                                                         zookeeper  214.906322
#
#                                                                           \
#                                                                      min
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   168.0
#                                                         camel      170.0
#                                                         cassandra  172.0
#                                                         flink      174.0
#                                                         groovy     176.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     131.0
#                                                         kafka      133.0
#                                                         spark      135.0
#                                                         zeppelin   137.0
#                                                         zookeeper  139.0
#
#                                                                           \
#                                                                      25%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   168.0
#                                                         camel      170.0
#                                                         cassandra  172.0
#                                                         flink      174.0
#                                                         groovy     176.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     131.0
#                                                         kafka      133.0
#                                                         spark      135.0
#                                                         zeppelin   137.0
#                                                         zookeeper  139.0
#
#                                                                           \
#                                                                      50%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   420.0
#                                                         camel      422.0
#                                                         cassandra  424.0
#                                                         flink      426.0
#                                                         groovy     428.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     383.0
#                                                         kafka      385.0
#                                                         spark      387.0
#                                                         zeppelin   389.0
#                                                         zookeeper  391.0
#
#                                                                           \
#                                                                      75%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   672.0
#                                                         camel      674.0
#                                                         cassandra  676.0
#                                                         flink      678.0
#                                                         groovy     680.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     635.0
#                                                         kafka      637.0
#                                                         spark      639.0
#                                                         zeppelin   641.0
#                                                         zookeeper  643.0
#
#                                                                           \
#                                                                      max
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   672.0
#                                                         camel      674.0
#                                                         cassandra  676.0
#                                                         flink      678.0
#                                                         groovy     680.0
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     635.0
#                                                         kafka      637.0
#                                                         spark      639.0
#                                                         zeppelin   641.0
#                                                         zookeeper  643.0
#
#                                                                   real_mcc  \
#                                                                      count
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq      12.0
#                                                         camel         12.0
#                                                         cassandra     12.0
#                                                         flink         12.0
#                                                         groovy        12.0
# ...                                                                    ...
# unscaled-randomforest pydriller            True         ignite        12.0
#                                                         kafka         12.0
#                                                         spark         12.0
#                                                         zeppelin      12.0
#                                                         zookeeper     12.0
#
#                                                                              \
#                                                                        mean
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   0.290477
#                                                         camel      0.172412
#                                                         cassandra  0.308405
#                                                         flink      0.332928
#                                                         groovy     0.234466
# ...                                                                     ...
# unscaled-randomforest pydriller            True         ignite     0.482549
#                                                         kafka      0.460771
#                                                         spark      0.438226
#                                                         zeppelin   0.395779
#                                                         zookeeper  0.453635
#
#                                                                    ...  \
#                                                                    ...
# model_type            metric_set           smell_models PROJECT    ...
# basic-linear-ridge    all-non-null-numeric False        activemq   ...
#                                                         camel      ...
#                                                         cassandra  ...
#                                                         flink      ...
#                                                         groovy     ...
# ...                                                                ...
# unscaled-randomforest pydriller            True         ignite     ...
#                                                         kafka      ...
#                                                         spark      ...
#                                                         zeppelin   ...
#                                                         zookeeper  ...
#
#                                                                   test_time_sec  \
#                                                                             75%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq        0.21825
#                                                         camel           1.89075
#                                                         cassandra       1.28125
#                                                         flink           1.50000
#                                                         groovy          0.46875
# ...                                                                         ...
# unscaled-randomforest pydriller            True         ignite          1.05100
#                                                         kafka           0.26975
#                                                         spark           0.12875
#                                                         zeppelin        0.15700
#                                                         zookeeper       0.11000
#
#                                                                           \
#                                                                      max
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   0.484
#                                                         camel      2.984
#                                                         cassandra  1.781
#                                                         flink      2.500
#                                                         groovy     1.078
# ...                                                                  ...
# unscaled-randomforest pydriller            True         ignite     1.219
#                                                         kafka      0.282
#                                                         spark      0.141
#                                                         zeppelin   0.172
#                                                         zookeeper  0.125
#
#                                                                   preparation_time_sec  \
#                                                                                  count
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq                  12.0
#                                                         camel                     12.0
#                                                         cassandra                 12.0
#                                                         flink                     12.0
#                                                         groovy                    12.0
# ...                                                                                ...
# unscaled-randomforest pydriller            True         ignite                    12.0
#                                                         kafka                     12.0
#                                                         spark                     12.0
#                                                         zeppelin                  12.0
#                                                         zookeeper                 12.0
#
#                                                                               \
#                                                                         mean
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   11.661500
#                                                         camel      14.208500
#                                                         cassandra  16.423250
#                                                         flink      16.768333
#                                                         groovy     17.761917
# ...                                                                      ...
# unscaled-randomforest pydriller            True         ignite      1.795750
#                                                         kafka       1.755167
#                                                         spark       1.750000
#                                                         zeppelin    1.769417
#                                                         zookeeper   1.713667
#
#                                                                              \
#                                                                         std
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   3.969340
#                                                         camel      4.466852
#                                                         cassandra  2.591974
#                                                         flink      2.671232
#                                                         groovy     3.893402
# ...                                                                     ...
# unscaled-randomforest pydriller            True         ignite     0.217593
#                                                         kafka      0.218457
#                                                         spark      0.201463
#                                                         zeppelin   0.218294
#                                                         zookeeper  0.198418
#
#                                                                            \
#                                                                       min
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq    6.344
#                                                         camel       6.610
#                                                         cassandra  10.266
#                                                         flink      12.672
#                                                         groovy     11.719
# ...                                                                   ...
# unscaled-randomforest pydriller            True         ignite      1.516
#                                                         kafka       1.453
#                                                         spark       1.453
#                                                         zeppelin    1.485
#                                                         zookeeper   1.438
#
#                                                                              \
#                                                                         25%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq    7.72250
#                                                         camel      12.08225
#                                                         cassandra  15.42600
#                                                         flink      15.05100
#                                                         groovy     15.12900
# ...                                                                     ...
# unscaled-randomforest pydriller            True         ignite      1.62900
#                                                         kafka       1.58950
#                                                         spark       1.57425
#                                                         zeppelin    1.60500
#                                                         zookeeper   1.52000
#
#                                                                             \
#                                                                        50%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   11.5310
#                                                         camel      15.0860
#                                                         cassandra  17.1560
#                                                         flink      16.5080
#                                                         groovy     18.1560
# ...                                                                    ...
# unscaled-randomforest pydriller            True         ignite      1.7190
#                                                         kafka       1.7185
#                                                         spark       1.7655
#                                                         zeppelin    1.7345
#                                                         zookeeper   1.7500
#
#                                                                              \
#                                                                         75%
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   14.88700
#                                                         camel      16.67550
#                                                         cassandra  18.38225
#                                                         flink      19.06250
#                                                         groovy     19.98900
# ...                                                                     ...
# unscaled-randomforest pydriller            True         ignite      1.92625
#                                                         kafka       1.92600
#                                                         spark       1.92575
#                                                         zeppelin    1.97275
#                                                         zookeeper   1.82850
#
#
#                                                                       max
# model_type            metric_set           smell_models PROJECT
# basic-linear-ridge    all-non-null-numeric False        activemq   17.532
#                                                         camel      21.391
#                                                         cassandra  18.891
#                                                         flink      20.953
#                                                         groovy     23.547
# ...                                                                   ...
# unscaled-randomforest pydriller            True         ignite      2.156
#                                                         kafka       2.078
#                                                         spark       2.094
#                                                         zeppelin    2.125
#                                                         zookeeper   2.031
#
# [252 rows x 208 columns]

# %%
import string

series = description.filter([("real_mcc", "50%"), ("real_precision", "50%")]).reset_index()
series["MCC"] = series[("real_mcc", "50%")]
series["Precision"] = series[("real_precision", "50%")]
series = series.drop(columns=[("real_mcc", "50%"), ("real_precision", "50%")])

incl_smells = series[series["smell_models"] == True].drop(columns=["smell_models"])
excl_smells = series[series["smell_models"] == False].drop(columns=["smell_models"])

final_series = incl_smells.merge(excl_smells, on=("metric_set", "model_type", "PROJECT"), suffixes=(" (smells)", " (no smells)"))

final_series = final_series[["metric_set", "model_type", "PROJECT", "MCC (smells)", "MCC (no smells)", "Precision (smells)", "Precision (no smells)"]]
final_series["metric_set"] = final_series["metric_set"].map(lambda x: x.replace("JAVAMETRICS", "JM"))
final_series["metric_set"] = final_series["metric_set"].map(lambda x: x.replace("_", "\\_"))

final_series["model_type"] = final_series["model_type"].map(MODEL_NAME_MAPPING)
final_series["metric_set"] = final_series["metric_set"].map(METRIC_SET_MAPPING)

remove_lowercase = str.maketrans('','', string.ascii_lowercase)
final_series["metric_set"] = final_series["metric_set"].map(lambda x: x.upper() if x.islower() else x.translate(remove_lowercase))
final_series = final_series.rename(columns={"model_type": "Model", "metric_set": "Metric set", "PROJECT": "Project"})

final_series = final_series.sort_values(by=['MCC (no smells)'], ascending=False)

final_series = final_series.reset_index(drop=True)
final_series.index += 1
final_series.style.to_latex(
    buf="performance-metrics-perproject.tex",
    caption="Prediction performance measures for per-project scenario",
    label="Appendix:DataTablePerProject",
    environment = "longtable"
)

final_series
# Out:
# C:\Users\Ja\AppData\Local\Temp\ipykernel_29016\431809221.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   incl_smells = series[series["smell_models"] == True].drop(columns=["smell_models"])
# C:\Users\Ja\AppData\Local\Temp\ipykernel_29016\431809221.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   excl_smells = series[series["smell_models"] == False].drop(columns=["smell_models"])
# C:\Users\Ja\AppData\Local\Temp\ipykernel_29016\431809221.py:11: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   final_series = incl_smells.merge(excl_smells, on=("metric_set", "model_type", "PROJECT"), suffixes=(" (smells)", " (no smells)"))
#     Metric set Model           Project MCC (smells) MCC (no smells)  \
#
# 1          ALL   URF       hadoop-hdfs     0.593378        0.592132
# 2           PR   URF       hadoop-hdfs     0.567679        0.554426
# 3           PR   URF  hadoop-mapreduce     0.542279        0.532191
# 4           PR   BLR  hadoop-mapreduce     0.386301        0.522315
# 5          ALL   URF  hadoop-mapreduce     0.511215        0.515821
# ..         ...   ...               ...          ...             ...
# 122         PD   BLR       hadoop-hdfs     0.218370        0.125343
# 123        ALL   UDT            groovy     0.113215        0.109729
# 124         PD   UDT             camel     0.105354        0.102116
# 125        ALL   UDT             camel     0.100250        0.100759
# 126         PD   BLR            groovy     0.135645        0.093787
#
#     Precision (smells) Precision (no smells)
#
# 1             0.907560              0.906695
# 2             0.916747              0.915531
# 3             0.802674              0.810931
# 4             0.753469              0.884211
# 5             0.770524              0.772391
# ..                 ...                   ...
# 122           0.866261              0.903226
# 123           0.260500              0.258782
# 124           0.185004              0.181469
# 125           0.177430              0.177651
# 126           0.376978              0.412245
#
# [126 rows x 7 columns]

# %%
series = description.filter([("real_mcc", "50%")]).reset_index()
series["mcc"] = series[("real_mcc", "50%")]
series
# Out:
#                 model_type            metric_set smell_models    PROJECT  \
#
# 0       basic-linear-ridge  all-non-null-numeric        False   activemq
# 1       basic-linear-ridge  all-non-null-numeric        False      camel
# 2       basic-linear-ridge  all-non-null-numeric        False  cassandra
# 3       basic-linear-ridge  all-non-null-numeric        False      flink
# 4       basic-linear-ridge  all-non-null-numeric        False     groovy
# ..                     ...                   ...          ...        ...
# 247  unscaled-randomforest             pydriller         True     ignite
# 248  unscaled-randomforest             pydriller         True      kafka
# 249  unscaled-randomforest             pydriller         True      spark
# 250  unscaled-randomforest             pydriller         True   zeppelin
# 251  unscaled-randomforest             pydriller         True  zookeeper
#
#      real_mcc       mcc
#           50%
# 0    0.290477  0.290477
# 1    0.172412  0.172412
# 2    0.308405  0.308405
# 3    0.332928  0.332928
# 4    0.234466  0.234466
# ..        ...       ...
# 247  0.482757  0.482757
# 248  0.458495  0.458495
# 249  0.441586  0.441586
# 250  0.394275  0.394275
# 251  0.452986  0.452986
#
# [252 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as pyplot

sns.set(rc={'figure.figsize': (8.0, 3.0)})

smellchart_data = results.filter(["real_mcc", "smell_models"])
smellchart_data["MCC"] = smellchart_data["real_mcc"]
smellchart_data["Include smell models"] = smellchart_data["smell_models"]

smells_mcc = sns.boxplot(
    smellchart_data, y="MCC", x="Include smell models"
)

smells_mcc.get_figure().savefig("projects_mcc_smells.png")
smells_mcc
# Out:
# <Axes: xlabel='Include smell models', ylabel='MCC'>

# %%
prec_smellchart_data = results.filter(["real_precision", "smell_models"])
prec_smellchart_data["Precision"] = prec_smellchart_data["real_precision"]
prec_smellchart_data["Include smell models"] = prec_smellchart_data["smell_models"]

smells_precision = sns.boxplot(
    prec_smellchart_data, y="Precision", x="Include smell models"
)

smells_precision.get_figure().savefig("projects_precision_smells.png")
smells_precision
# Out:
# <Axes: xlabel='Include smell models', ylabel='Precision'>

# %%
MODEL_NAME_MAPPING = {
    "basic-linear-ridge": "BLR",
    "unscaled-linear": "ULR",
    "basic-randomforest": "BRF",
    "unscaled-randomforest": "URF",
    "unscaled-decisiontree": "UDT",
    "basic-adaboost": "BAB",
    "basic-gradientboost": "BGB"
}


modeltype_data = results.loc[results.smell_models == False].filter(["real_mcc", "model_type"])
modeltype_data["MCC"] = modeltype_data["real_mcc"]
modeltype_data["ML model"] = modeltype_data["model_type"].map(MODEL_NAME_MAPPING)

models_mcc = sns.boxplot(
    modeltype_data, y="MCC", x="ML model"
)

models_mcc.get_figure().savefig("projects_mcc_models.png")
models_mcc
# Out:
# <Axes: xlabel='ML model', ylabel='MCC'>

# %%
prec_modeltype_data = results.loc[results.smell_models == False].filter(["real_precision", "model_type"])
prec_modeltype_data["Precision"] = prec_modeltype_data["real_precision"]
prec_modeltype_data["ML model"] = prec_modeltype_data["model_type"].map(MODEL_NAME_MAPPING)

models_precision = sns.boxplot(
    prec_modeltype_data, y="Precision", x="ML model"
)

models_precision.get_figure().savefig("projects_precision_models.png")
models_precision
# Out:
# <Axes: xlabel='ML model', ylabel='Precision'>

# %%
METRIC_SET_MAPPING = {
    "none": "NONE",
    "all-non-null-numeric": "ALL",
    "pydriller": "PyD",
    "product": "PD",
    "process": "PR",
    "javametrics-numeric": "JM",
    "javametrics2": "JM2",
    "javametrics2-process": "JM2R",
    "javametrics2-product": "JM2D",
    "pmd": "PMD"
}


metrictype_data = results.loc[results.smell_models == False].filter(["real_mcc", "metric_set"])
metrictype_data["Metric set"] = metrictype_data["metric_set"].map(METRIC_SET_MAPPING)

metrics_mcc = sns.boxplot(
    metrictype_data, y="real_mcc", x="Metric set"
)

metrics_mcc.set(xlabel = "Metric set", ylabel = "MCC")

metrics_mcc.get_figure().savefig("projects_mcc_metrics.png")
metrics_mcc
# Out:
# <Axes: xlabel='Metric set', ylabel='MCC'>

# %%
mcc_project_data = results.loc[results.smell_models == False].filter(["real_mcc", "PROJECT"])
mcc_project_data["MCC"] = mcc_project_data["real_mcc"]
mcc_project_data["Project"] = mcc_project_data["PROJECT"].map(PROJECT_NAME_MAPPING)
sns.set(rc={'figure.figsize': (8.0, 4.5)})

models_mcc = sns.boxplot(
    mcc_project_data, y="MCC", x="Project"
)
models_mcc.set_xticklabels(models_mcc.get_xticklabels(), rotation=90)
pyplot.tight_layout()

models_mcc.get_figure().savefig("projects_mcc_project.png")
models_mcc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       3 mcc_project_data["Project"] = mcc_project_data["PROJECT"].map(PROJECT_NAME_MAPPING)
#       4 sns.set(rc={'figure.figsize': (8.0, 4.5)})
# ----> 6 models_mcc = sns.boxplot(
#       7     mcc_project_data, y="MCC", x="Project"
#       8 )
#       9 models_mcc.set_xticklabels(models_mcc.get_xticklabels(), rotation=90)
#      10 pyplot.tight_layout()
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\seaborn\categorical.py:1617, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1614     dodge = p._dodge_needed()
#    1616 if p.var_types.get(p.orient) == "categorical" or not native_scale:
# -> 1617     p.scale_categorical(p.orient, order=order, formatter=formatter)
#    1619 p._attach(ax, log_scale=log_scale)
#    1621 # Deprecations to remove in v0.14.0.
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\seaborn\_base.py:1447, in VectorPlotter.scale_categorical(self, axis, order, formatter)
#    1444 self.var_types[axis] = "categorical"
#    1446 # Put the string-typed categorical vector back into the plot_data structure
# -> 1447 self.plot_data[axis] = cat_data
#    1449 return self
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\frame.py:5263, in DataFrame._sanitize_column(self, value)
#    5261     if not isinstance(value, Series):
#    5262         value = Series(value)
# -> 5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
#    5266     com.require_length_match(value, self.index)
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\frame.py:12692, in _reindex_for_setitem(value, index)
#   12688 except ValueError as err:
#   12689     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12690     if not value.index.is_unique:
#   12691         # duplicate axis
# > 12692         raise err
#   12694     raise TypeError(
#   12695         "incompatible index of inserted column with frame index"
#   12696     ) from err
#   12697 return reindexed_value, None
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\frame.py:12687, in _reindex_for_setitem(value, index)
#   12685 # GH#4107
#   12686 try:
# > 12687     reindexed_value = value.reindex(index)._values
#   12688 except ValueError as err:
#   12689     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12690     if not value.index.is_unique:
#   12691         # duplicate axis
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\series.py:5153, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5136 @doc(
#    5137     NDFrame.reindex,  # type: ignore[has-type]
#    5138     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5151     tolerance=None,
#    5152 ) -> Series:
# -> 5153     return super().reindex(
#    5154         index=index,
#    5155         method=method,
#    5156         copy=copy,
#    5157         level=level,
#    5158         fill_value=fill_value,
#    5159         limit=limit,
#    5160         tolerance=tolerance,
#    5161     )
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\generic.py:5610, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5607     return self._reindex_multi(axes, copy, fill_value)
#    5609 # perform the reindex on the axes
# -> 5610 return self._reindex_axes(
#    5611     axes, level, limit, tolerance, method, fill_value, copy
#    5612 ).__finalize__(self, method="reindex")
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\generic.py:5633, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5630     continue
#    5632 ax = self._get_axis(a)
# -> 5633 new_index, indexer = ax.reindex(
#    5634     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635 )
#    5637 axis = self._get_axis_number(a)
#    5638 obj = obj._reindex_with_indexers(
#    5639     {axis: [new_index, indexer]},
#    5640     fill_value=fill_value,
#    5641     copy=copy,
#    5642     allow_dups=False,
#    5643 )
#
# File L:\PhD\defect-prediction\venv\lib\site-packages\pandas\core\indexes\base.py:4429, in Index.reindex(self, target, method, level, limit, tolerance)
#    4426     raise ValueError("cannot handle a non-unique multi-index!")
#    4427 elif not self.is_unique:
#    4428     # GH#42568
# -> 4429     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4430 else:
#    4431     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
prec_project_data = results.loc[results.smell_models == False].filter(["real_precision", "PROJECT"])
prec_project_data["Precision"] = prec_project_data["real_precision"]
prec_project_data["Project"] = prec_project_data["PROJECT"].map(PROJECT_NAME_MAPPING)

models_precision = sns.boxplot(
    prec_project_data, y="Precision", x="Project"
)

models_precision.set_xticklabels(models_precision.get_xticklabels(), rotation=90)
pyplot.tight_layout()

models_precision.get_figure().savefig("projects_precision_project.png")
models_precision
# Out:
# <AxesSubplot: xlabel='Project', ylabel='Precision'>

# %%
metrictype_data = results.loc[results.smell_models == False].filter(["real_precision", "metric_set"])
metrictype_data["Metric set"] = metrictype_data["metric_set"].map(METRIC_SET_MAPPING)

metrics_precision = sns.boxplot(
    metrictype_data, y="real_precision", x="Metric set"
)

metrics_precision.set(xlabel="Metric set", ylabel="Precision")

metrics_precision.get_figure().savefig("projects_precision_metrics.png")
metrics_precision
# Out:
# <AxesSubplot: xlabel='Metric set', ylabel='Precision'>

# %%
final_series.groupby("Project").describe()
# Out:
#                  MCC (smells)                                          \
#
#                         count      mean       std       min       25%
# Project
# activemq                  9.0  0.278600  0.078749  0.163115  0.202987
# camel                     9.0  0.171731  0.066581  0.100250  0.123780
# cassandra                 9.0  0.325775  0.085435  0.227214  0.268524
# flink                     9.0  0.343800  0.073585  0.246613  0.269402
# groovy                    9.0  0.197364  0.061809  0.113215  0.158988
# hadoop-hdfs               9.0  0.357974  0.142914  0.218370  0.262941
# hadoop-mapreduce          9.0  0.366207  0.108453  0.223916  0.276166
# hbase                     9.0  0.302622  0.066970  0.229013  0.253037
# hive                      9.0  0.316119  0.072676  0.235939  0.242820
# ignite                    9.0  0.373967  0.098138  0.239140  0.286278
# kafka                     9.0  0.376154  0.098072  0.253046  0.262798
# spark                     9.0  0.323579  0.105423  0.198998  0.229753
# zeppelin                  9.0  0.326193  0.071477  0.219544  0.242507
# zookeeper                 9.0  0.361909  0.114955  0.216363  0.258864
#
#                                                MCC (no smells)            ...  \
#                                                                           ...
#                        50%       75%       max           count      mean  ...
# Project                                                                   ...
# activemq          0.299561  0.342067  0.375397             9.0  0.268124  ...
# camel             0.153425  0.224678  0.274298             9.0  0.171604  ...
# cassandra         0.307674  0.396422  0.454359             9.0  0.317546  ...
# flink             0.355894  0.418084  0.430830             9.0  0.345067  ...
# groovy            0.171754  0.252399  0.281721             9.0  0.189680  ...
# hadoop-hdfs       0.293996  0.428231  0.593378             9.0  0.353772  ...
# hadoop-mapreduce  0.363610  0.405920  0.542279             9.0  0.381775  ...
# hbase             0.279036  0.371114  0.400814             9.0  0.287866  ...
# hive              0.305873  0.389159  0.418859             9.0  0.306066  ...
# ignite            0.367503  0.482757  0.496950             9.0  0.378081  ...
# kafka             0.389429  0.458495  0.497081             9.0  0.365915  ...
# spark             0.305336  0.441586  0.460033             9.0  0.319794  ...
# zeppelin          0.357603  0.388393  0.394275             9.0  0.309545  ...
# zookeeper         0.374187  0.452986  0.509616             9.0  0.352097  ...
#
#                  Precision (smells)           Precision (no smells)            \
#
#                                 75%       max                 count      mean
# Project
# activemq                   0.574943  0.614667                   9.0  0.511595
# camel                      0.268686  0.278919                   9.0  0.223340
# cassandra                  0.698431  0.733301                   9.0  0.601730
# flink                      0.476480  0.508732                   9.0  0.445283
# groovy                     0.415791  0.446625                   9.0  0.363216
# hadoop-hdfs                0.907560  0.916747                   9.0  0.881830
# hadoop-mapreduce           0.775720  0.802674                   9.0  0.790860
# hbase                      0.672914  0.681343                   9.0  0.624587
# hive                       0.832933  0.848698                   9.0  0.799938
# ignite                     0.536076  0.589910                   9.0  0.483153
# kafka                      0.744571  0.753323                   9.0  0.709210
# spark                      0.689332  0.696160                   9.0  0.634866
# zeppelin                   0.733415  0.762627                   9.0  0.680260
# zookeeper                  0.665414  0.699026                   9.0  0.628190
#
#
#
#                        std       min       25%       50%       75%       max
# Project
# activemq          0.107581  0.360714  0.391366  0.554090  0.578947  0.637285
# camel             0.041757  0.177651  0.181731  0.218525  0.267043  0.279098
# cassandra         0.089994  0.531863  0.536245  0.547088  0.696132  0.749483
# flink             0.066097  0.364971  0.387129  0.461778  0.480738  0.533919
# groovy            0.071355  0.258782  0.313270  0.402619  0.413742  0.454278
# hadoop-hdfs       0.036271  0.828658  0.852046  0.903226  0.911978  0.920231
# hadoop-mapreduce  0.055553  0.693578  0.769757  0.776905  0.810931  0.884211
# hbase             0.061150  0.553179  0.576007  0.597285  0.679727  0.705936
# hive              0.051391  0.736129  0.766080  0.781233  0.837899  0.882556
# ignite            0.109550  0.342290  0.386576  0.527050  0.586729  0.610513
# kafka             0.075206  0.594641  0.639566  0.743395  0.751814  0.810219
# spark             0.070183  0.542135  0.550973  0.642697  0.692187  0.710380
# zeppelin          0.076145  0.571055  0.594048  0.701657  0.737778  0.770045
# zookeeper         0.070531  0.542467  0.557873  0.643443  0.688275  0.721725
#
# [14 rows x 32 columns]

# %%
from effect_size_analysis.cliff_delta import cliff_delta


def calculate_cliff_deltas(all_results, column):
    descriptors = all_results[column].unique()
    cds = {}
    descriptors_1 = []
    descriptors_2 = []
    cd_mcc = []
    cd_mcc_min = []
    cd_mcc_max = []
    cd_prec = []
    cd_prec_min = []
    cd_prec_max = []

    descriptors_count = len(descriptors)
    for i in range(descriptors_count):
        item_1 = results[results[column] == descriptors[i]]
        for j in range(i + 1, descriptors_count):
            item_2 = results[results[column] == descriptors[j]]
            descriptors_1.append(descriptors[i])
            descriptors_2.append(descriptors[j])
            cd_mcc_curr = cliff_delta(item_1["real_mcc"], item_2["real_mcc"], alpha=0.05, accurate_ci=True)
            cd_mcc.append(cd_mcc_curr[0])
            cd_mcc_min.append(cd_mcc_curr[1][0])
            cd_mcc_max.append(cd_mcc_curr[1][1])
            cd_prec_curr = cliff_delta(item_1["real_precision"], item_2["real_precision"], alpha=0.05, accurate_ci=True)
            cd_prec.append(cd_prec_curr[0])
            cd_prec_min.append(cd_prec_curr[1][0])
            cd_prec_max.append(cd_prec_curr[1][1])
    return pd.DataFrame(
        {"descriptor_1": descriptors_1, "descriptor_2": descriptors_2, "CD MCC min": cd_mcc_min, "CD MCC": cd_mcc,
         "CD MCC max": cd_mcc_max, "CD precision min": cd_prec_min, "CD precision": cd_prec,
         "CD precision max": cd_prec_max})

# %%
calculate_cliff_deltas(results, "model_type")
# Out:
#             descriptor_1           descriptor_2  CD MCC min    CD MCC  \
# 0     basic-linear-ridge  unscaled-randomforest   -0.749017 -0.716553
# 1     basic-linear-ridge  unscaled-decisiontree    0.462190  0.508645
# 2  unscaled-randomforest  unscaled-decisiontree    0.886257  0.905628
#
#    CD MCC max  CD precision min  CD precision  CD precision max
# 0   -0.680657         -0.248415     -0.199464         -0.149496
# 1    0.552316          0.190118      0.239843          0.288341
# 2    0.921837          0.352210      0.399765          0.445261

# %%
calculate_cliff_deltas(results, "metric_set")
# Out:
#   descriptor_1          descriptor_2  CD MCC min    CD MCC  CD MCC max  \
# 0      process             pydriller    0.163877  0.213337    0.261727
# 1      process  all-non-null-numeric   -0.011958  0.038582    0.088925
# 2    pydriller  all-non-null-numeric   -0.229508 -0.180496   -0.130570
#
#    CD precision min  CD precision  CD precision max
# 0         -0.121528     -0.071471         -0.021051
# 1          0.001514      0.051943          0.102108
# 2          0.070378      0.120625          0.170262

# %%
calculate_cliff_deltas(results, "smell_models")
# Out:
#    descriptor_1  descriptor_2  CD MCC min    CD MCC  CD MCC max  \
# 0         False          True   -0.074519 -0.033425    0.007783
#
#    CD precision min  CD precision  CD precision max
# 0         -0.006487      0.034678          0.075726

# %%
calculate_cliff_deltas(results, "PROJECT")
# Out:
# L:\PhD\defect-prediction\runners\init\lib\site-packages\effect_size_analysis\cliff_delta.py:94: RuntimeWarning: invalid value encountered in double_scalars
#   (delta_val - delta_val ** 3 - ci_size) / denom_corretion,
# L:\PhD\defect-prediction\runners\init\lib\site-packages\effect_size_analysis\cliff_delta.py:95: RuntimeWarning: invalid value encountered in double_scalars
#   (delta_val - delta_val ** 3 + ci_size) / denom_corretion,
#    descriptor_1 descriptor_2  CD MCC min    CD MCC  CD MCC max  \
# 0      activemq        camel    0.599828  0.678884    0.744813
# 1      activemq    cassandra   -0.414499 -0.315458   -0.209031
# 2      activemq        flink   -0.548033 -0.460391   -0.362749
# 3      activemq       groovy    0.492379  0.581019    0.657730
# 4      activemq  hadoop-hdfs   -0.427411 -0.328361   -0.221521
# ..          ...          ...         ...       ...         ...
# 86        kafka     zeppelin    0.280168  0.384516    0.479884
# 87        kafka    zookeeper   -0.028923  0.081962    0.190854
# 88        spark     zeppelin   -0.159454 -0.044153    0.072337
# 89        spark    zookeeper   -0.334563 -0.232082   -0.124175
# 90     zeppelin    zookeeper   -0.294358 -0.187757   -0.076541
#
#     CD precision min  CD precision  CD precision max
# 0                NaN      1.000000               NaN
# 1          -0.293679     -0.184799         -0.071186
# 2           0.270949      0.393347          0.503228
# 3           0.549926      0.637860          0.711808
# 4                NaN     -1.000000               NaN
# ..               ...           ...               ...
# 86          0.142249      0.250664          0.353137
# 87          0.556551      0.641975          0.713967
# 88         -0.509467     -0.416024         -0.312883
# 89         -0.001422      0.108389          0.215618
# 90          0.387366      0.484096          0.570284
#
# [91 rows x 8 columns]

# %%
results[['metric_set', 'model_type', 'PROJECT', 'smell_models', 'real_mcc', 'real_precision']]
# Out:
#                metric_set             model_type    PROJECT  smell_models  \
# 0                 process     basic-linear-ridge   activemq         False
# 1                 process     basic-linear-ridge   activemq          True
# 2                 process     basic-linear-ridge      camel         False
# 3                 process     basic-linear-ridge      camel          True
# 4                 process     basic-linear-ridge  cassandra         False
# ..                    ...                    ...        ...           ...
# 751  all-non-null-numeric  unscaled-decisiontree      spark          True
# 752  all-non-null-numeric  unscaled-decisiontree   zeppelin         False
# 753  all-non-null-numeric  unscaled-decisiontree   zeppelin          True
# 754  all-non-null-numeric  unscaled-decisiontree  zookeeper         False
# 755  all-non-null-numeric  unscaled-decisiontree  zookeeper          True
#
#      real_mcc  real_precision
# 0    0.257831        0.547022
# 1    0.302461        0.543554
# 2    0.147381        0.201429
# 3    0.153425        0.203684
# 4    0.284922        0.539696
# ..        ...             ...
# 751  0.199804        0.545166
# 752  0.256431        0.596958
# 753  0.242811        0.592885
# 754  0.255142        0.546419
# 755  0.235201        0.530457
#
# [3024 rows x 6 columns]
